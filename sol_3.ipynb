# %%
import cv2
from ultralytics import YOLO
from collections import defaultdict

# Load the YOLO model
model = YOLO('yolo11l.pt')

# %%
class_list = model.names 
class_list
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %%
# Open the video file
cap = cv2.VideoCapture('test_videos/3.mp4')

# %%
import cv2
from ultralytics import YOLO
from collections import defaultdict

# Load the YOLO model
model = YOLO('yolo11l.pt')

class_list = model.names 
#class_list

# Open the video file
cap = cv2.VideoCapture('test_videos/3.mp4')

line_y_red = 430  # Red line position

# Dictionary to store object counts by class
class_counts = defaultdict(int)

# Dictionary to keep track of object IDs that have crossed the line
crossed_ids = set()

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO tracking on the frame
    results = model.track(frame, persist=True, classes = [1,2,3,5,6,7]) 
    #print(results)

    # Ensure results are not empty
    if results[0].boxes.data is not None:
        # Get the detected boxes, their class indices, and track IDs
        boxes = results[0].boxes.xyxy.cpu()
        track_ids = results[0].boxes.id.int().cpu().tolist()
        class_indices = results[0].boxes.cls.int().cpu().tolist()
        confidences = results[0].boxes.conf.cpu()

        cv2.line(frame, (690, line_y_red), (1130, line_y_red), (0, 0, 255), 3)
        #cv2.putText(frame, 'Red Line', (690, line_y_red - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)


        

        # Loop through each detected object
        for box, track_id, class_idx, conf in zip(boxes, track_ids, class_indices, confidences):
            x1, y1, x2, y2 = map(int, box)
            cx = (x1 + x2) // 2  # Calculate the center point
            cy = (y1 + y2) // 2            

            class_name = class_list[class_idx]

            cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
            
            cv2.putText(frame, f"ID: {track_id} {class_name}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2) 


            # Check if the object has crossed the red line
            if cy > line_y_red and track_id not in crossed_ids:
                # Mark the object as crossed
                crossed_ids.add(track_id)
                class_counts[class_name] += 1


        # Display the counts on the frame
        y_offset = 30
        for class_name, count in class_counts.items():
            cv2.putText(frame, f"{class_name}: {count}", (50, y_offset),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
            y_offset += 30

    
    
    # Show the frame
    cv2.imshow("YOLO Object Tracking & Counting", frame)    
    
    # Exit loop if 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 2 cars, 1 bus, 269.2ms
# Speed: 5.6ms preprocess, 269.2ms inference, 153.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 63.7ms
# Speed: 3.0ms preprocess, 63.7ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 64.4ms
# Speed: 3.0ms preprocess, 64.4ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 62.3ms
# Speed: 2.0ms preprocess, 62.3ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 64.2ms
# Speed: 2.5ms preprocess, 64.2ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 buss, 63.8ms
# Speed: 3.0ms preprocess, 63.8ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 buss, 62.6ms
# Speed: 3.0ms preprocess, 62.6ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 buss, 63.7ms
# Speed: 3.0ms preprocess, 63.7ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 buss, 66.6ms
# Speed: 4.0ms preprocess, 66.6ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 buss, 65.8ms
# Speed: 3.0ms preprocess, 65.8ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 buss, 64.6ms
# Speed: 3.4ms preprocess, 64.6ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 buss, 64.9ms
# Speed: 2.8ms preprocess, 64.9ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 buss, 65.2ms
# Speed: 3.5ms preprocess, 65.2ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 buss, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 buss, 63.8ms
# Speed: 2.2ms preprocess, 63.8ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 buss, 88.8ms
# Speed: 3.7ms preprocess, 88.8ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 buss, 62.8ms
# Speed: 3.0ms preprocess, 62.8ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 buss, 61.7ms
# Speed: 3.0ms preprocess, 61.7ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 buss, 61.6ms
# Speed: 3.0ms preprocess, 61.6ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 buss, 60.6ms
# Speed: 2.8ms preprocess, 60.6ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 buss, 62.6ms
# Speed: 2.0ms preprocess, 62.6ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 buss, 60.0ms
# Speed: 3.1ms preprocess, 60.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 motorcycle, 2 buss, 61.9ms
# Speed: 2.0ms preprocess, 61.9ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 motorcycle, 2 buss, 66.6ms
# Speed: 3.3ms preprocess, 66.6ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 motorcycle, 2 buss, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 motorcycle, 2 buss, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 motorcycle, 2 buss, 67.3ms
# Speed: 2.5ms preprocess, 67.3ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 motorcycle, 2 buss, 62.9ms
# Speed: 2.0ms preprocess, 62.9ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 motorcycle, 2 buss, 121.9ms
# Speed: 3.6ms preprocess, 121.9ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 motorcycle, 2 buss, 61.4ms
# Speed: 2.0ms preprocess, 61.4ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 motorcycle, 2 buss, 68.3ms
# Speed: 3.0ms preprocess, 68.3ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 motorcycle, 2 buss, 63.9ms
# Speed: 3.0ms preprocess, 63.9ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 motorcycle, 2 buss, 61.3ms
# Speed: 3.0ms preprocess, 61.3ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 motorcycles, 2 buss, 63.2ms
# Speed: 3.5ms preprocess, 63.2ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 motorcycles, 2 buss, 64.1ms
# Speed: 2.5ms preprocess, 64.1ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 motorcycles, 2 buss, 62.6ms
# Speed: 2.0ms preprocess, 62.6ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 motorcycles, 2 buss, 120.4ms
# Speed: 3.0ms preprocess, 120.4ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 motorcycles, 2 buss, 62.1ms
# Speed: 3.6ms preprocess, 62.1ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 motorcycles, 2 buss, 64.4ms
# Speed: 2.5ms preprocess, 64.4ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 motorcycles, 2 buss, 61.3ms
# Speed: 2.3ms preprocess, 61.3ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 motorcycles, 2 buss, 62.2ms
# Speed: 2.7ms preprocess, 62.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 motorcycles, 2 buss, 67.1ms
# Speed: 3.8ms preprocess, 67.1ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 motorcycles, 2 buss, 62.4ms
# Speed: 2.5ms preprocess, 62.4ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 motorcycles, 2 buss, 61.2ms
# Speed: 2.4ms preprocess, 61.2ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 motorcycles, 2 buss, 63.0ms
# Speed: 2.5ms preprocess, 63.0ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 motorcycles, 2 buss, 65.0ms
# Speed: 3.1ms preprocess, 65.0ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 motorcycles, 2 buss, 62.3ms
# Speed: 3.5ms preprocess, 62.3ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 motorcycles, 2 buss, 61.9ms
# Speed: 2.5ms preprocess, 61.9ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 motorcycles, 2 buss, 62.5ms
# Speed: 2.0ms preprocess, 62.5ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 motorcycles, 2 buss, 61.8ms
# Speed: 2.6ms preprocess, 61.8ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 90.3ms
# Speed: 2.9ms preprocess, 90.3ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 60.7ms
# Speed: 3.1ms preprocess, 60.7ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 61.7ms
# Speed: 2.0ms preprocess, 61.7ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 64.6ms
# Speed: 2.0ms preprocess, 64.6ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 75.8ms
# Speed: 2.0ms preprocess, 75.8ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 66.3ms
# Speed: 3.0ms preprocess, 66.3ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 61.9ms
# Speed: 2.0ms preprocess, 61.9ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 63.6ms
# Speed: 3.0ms preprocess, 63.6ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 67.3ms
# Speed: 3.0ms preprocess, 67.3ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 62.1ms
# Speed: 2.5ms preprocess, 62.1ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 61.9ms
# Speed: 2.0ms preprocess, 61.9ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 61.3ms
# Speed: 3.0ms preprocess, 61.3ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 motorcycles, 2 buss, 63.2ms
# Speed: 2.5ms preprocess, 63.2ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 motorcycles, 2 buss, 63.7ms
# Speed: 3.0ms preprocess, 63.7ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 motorcycles, 2 buss, 62.1ms
# Speed: 2.5ms preprocess, 62.1ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 motorcycles, 2 buss, 64.4ms
# Speed: 2.0ms preprocess, 64.4ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 82.7ms
# Speed: 3.5ms preprocess, 82.7ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 61.8ms
# Speed: 3.5ms preprocess, 61.8ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 61.5ms
# Speed: 3.0ms preprocess, 61.5ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 75.3ms
# Speed: 4.0ms preprocess, 75.3ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 1 bus, 1 truck, 61.9ms
# Speed: 3.0ms preprocess, 61.9ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 motorcycles, 2 buss, 1 truck, 103.1ms
# Speed: 5.0ms preprocess, 103.1ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 62.7ms
# Speed: 3.0ms preprocess, 62.7ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 61.7ms
# Speed: 3.0ms preprocess, 61.7ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 68.1ms
# Speed: 2.0ms preprocess, 68.1ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 62.8ms
# Speed: 2.8ms preprocess, 62.8ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 motorcycles, 2 buss, 61.2ms
# Speed: 3.0ms preprocess, 61.2ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 motorcycles, 2 buss, 62.7ms
# Speed: 2.0ms preprocess, 62.7ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 motorcycles, 2 buss, 63.5ms
# Speed: 1.7ms preprocess, 63.5ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 motorcycles, 2 buss, 62.3ms
# Speed: 3.0ms preprocess, 62.3ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 62.3ms
# Speed: 2.5ms preprocess, 62.3ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 62.8ms
# Speed: 3.2ms preprocess, 62.8ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 62.1ms
# Speed: 2.3ms preprocess, 62.1ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 61.7ms
# Speed: 2.0ms preprocess, 61.7ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 62.7ms
# Speed: 2.0ms preprocess, 62.7ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 motorcycles, 2 buss, 1 truck, 61.4ms
# Speed: 2.0ms preprocess, 61.4ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 62.5ms
# Speed: 3.4ms preprocess, 62.5ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 62.8ms
# Speed: 2.3ms preprocess, 62.8ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 motorcycles, 2 buss, 1 truck, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 69.3ms
# Speed: 4.5ms preprocess, 69.3ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 62.5ms
# Speed: 2.5ms preprocess, 62.5ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 61.2ms
# Speed: 2.0ms preprocess, 61.2ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 63.3ms
# Speed: 2.0ms preprocess, 63.3ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 63.5ms
# Speed: 3.0ms preprocess, 63.5ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 63.2ms
# Speed: 3.5ms preprocess, 63.2ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 65.6ms
# Speed: 2.0ms preprocess, 65.6ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 64.0ms
# Speed: 3.0ms preprocess, 64.0ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 89.8ms
# Speed: 4.0ms preprocess, 89.8ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 motorcycles, 2 buss, 86.0ms
# Speed: 3.0ms preprocess, 86.0ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 motorcycles, 2 buss, 82.6ms
# Speed: 3.5ms preprocess, 82.6ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 motorcycles, 2 buss, 1 truck, 62.0ms
# Speed: 3.1ms preprocess, 62.0ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 motorcycles, 2 buss, 1 truck, 65.5ms
# Speed: 2.1ms preprocess, 65.5ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 motorcycles, 2 buss, 1 truck, 70.7ms
# Speed: 2.0ms preprocess, 70.7ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 motorcycles, 2 buss, 1 truck, 73.2ms
# Speed: 2.0ms preprocess, 73.2ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 motorcycles, 2 buss, 1 truck, 71.1ms
# Speed: 2.5ms preprocess, 71.1ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 motorcycles, 2 buss, 1 truck, 61.8ms
# Speed: 2.0ms preprocess, 61.8ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 6 motorcycles, 2 buss, 1 truck, 62.3ms
# Speed: 2.5ms preprocess, 62.3ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 6 motorcycles, 2 buss, 1 truck, 61.8ms
# Speed: 3.0ms preprocess, 61.8ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 6 motorcycles, 2 buss, 1 truck, 61.9ms
# Speed: 3.0ms preprocess, 61.9ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 7 motorcycles, 2 buss, 1 truck, 62.7ms
# Speed: 3.0ms preprocess, 62.7ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 7 motorcycles, 2 buss, 1 truck, 62.4ms
# Speed: 3.5ms preprocess, 62.4ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 7 motorcycles, 2 buss, 1 truck, 63.6ms
# Speed: 3.0ms preprocess, 63.6ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 7 motorcycles, 2 buss, 1 truck, 65.3ms
# Speed: 3.0ms preprocess, 65.3ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 motorcycles, 2 buss, 63.3ms
# Speed: 3.0ms preprocess, 63.3ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 motorcycles, 2 buss, 63.8ms
# Speed: 2.8ms preprocess, 63.8ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 motorcycles, 2 buss, 62.4ms
# Speed: 2.3ms preprocess, 62.4ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 motorcycles, 2 buss, 61.9ms
# Speed: 1.5ms preprocess, 61.9ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 motorcycles, 2 buss, 65.6ms
# Speed: 2.5ms preprocess, 65.6ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 motorcycles, 2 buss, 62.9ms
# Speed: 3.0ms preprocess, 62.9ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 motorcycles, 2 buss, 64.1ms
# Speed: 3.1ms preprocess, 64.1ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 motorcycles, 2 buss, 76.7ms
# Speed: 4.4ms preprocess, 76.7ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 motorcycles, 2 buss, 62.9ms
# Speed: 3.0ms preprocess, 62.9ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 motorcycles, 2 buss, 63.6ms
# Speed: 3.0ms preprocess, 63.6ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 motorcycles, 2 buss, 71.7ms
# Speed: 3.0ms preprocess, 71.7ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 motorcycles, 2 buss, 62.1ms
# Speed: 2.5ms preprocess, 62.1ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 motorcycles, 2 buss, 68.1ms
# Speed: 3.2ms preprocess, 68.1ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 motorcycles, 2 buss, 64.6ms
# Speed: 3.0ms preprocess, 64.6ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 motorcycles, 2 buss, 62.4ms
# Speed: 2.0ms preprocess, 62.4ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 motorcycles, 2 buss, 62.3ms
# Speed: 2.0ms preprocess, 62.3ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 motorcycles, 2 buss, 60.2ms
# Speed: 3.0ms preprocess, 60.2ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 motorcycles, 2 buss, 69.4ms
# Speed: 3.0ms preprocess, 69.4ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 7 motorcycles, 2 buss, 1 truck, 71.0ms
# Speed: 3.5ms preprocess, 71.0ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 7 motorcycles, 2 buss, 1 truck, 63.1ms
# Speed: 2.0ms preprocess, 63.1ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
